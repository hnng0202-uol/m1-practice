# %%
from scripts.data_extraction_M1 import extract_answers_sequence

results = extract_answers_sequence("data/a1.txt")

print(f"Total Questions Parsed: {len(results)}")
print(f"First 10 answers: {results[:10]}")
# Out:
# Total Questions Parsed: 100
# First 10 answers: [1, 3, 3, 4, 1, 2, 3, 4, 2, 2]

# %%
comment ......
